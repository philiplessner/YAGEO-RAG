# %% [markdown]
# ## Notebook For Viewing HTML and Elements, Chunks, Documents ##
#
# * HTML obtained via Requests and Filtered by Beautiful Soup
# * Elements obtained by Unstructured partition_html
# * Chunks from Unstructured chunk_by_title
# * Document format is from LangChain

# %%
import json
from IPython.core.display import HTML
import requests
from bs4 import BeautifulSoup
from unstructured.partition.html import partition_html
from unstructured.chunking.title import chunk_by_title
from langchain_core.documents.base import Document
from langchain_community.vectorstores import Chroma
from langchain_openai import OpenAIEmbeddings

# %% [markdown]
# First let's get the webpage of interest and filter according to the div(s) we think are interesting.

# %%
# Web page to fetch
html_source =  "https://www.chilisin.com/en-global/Inductor/index/emi_common"
# What type of tag do we want to filter by?
tag_type = "div"
# What is the class name to filter?
tag_class = 'container'

# %% [markdown]
# Now use requests to get the webpage html text and Beautiful Soup to filter it

# %%
def get_filtered_html(html_source:str, tag_type:str, tag_class:str):
    page = requests.get(html_source)
    soup = BeautifulSoup(page.text, 'html.parser')
    output = soup.find_all(tag_type, class_=tag_class)
    return output

# %%
html_output = get_filtered_html(html_source, tag_type, tag_class)

# %%
# Raw HTML Output
print(html_output[0])
# Out:
# <div class="container">
# <div class="banner">
# <img src="/upload/website/banner/chilisin_product_banner_18062116137.jpg"/>
# </div>
# <div class="unit">
# <div class="crumbs_block clearfix">
# <ul class="crumbs no_ul clearfix">
# <li>
# <a href="/en-global/home/index">
# 					Home					</a>
# </li>
# <li><a href="/en-global/Inductor/index">Products</a></li>
# </ul>
# </div>
# </div>
# <div class="main_content">
# <h1 class="main_title">EMI-Common Mode Choke</h1>
# <script type="text/javascript">
#
# 	$(window).load(function()
# 	{
# 		var url = window.location.toString();
# 	    var id = url.split('#')[1];
# 	   	if(id)
# 	   	{
# 		    var t = $('#'+id).offset().top;
# 		   $('html,body').animate({scrollTop:(t)}, 1000);
# 		}
# 	});
# </script>
# <!-- Search -->
# <div class="top_search_block">
# <div class="search_sel_block lv1 clearfix">
# <div class="search_title hidden_m">Search by : </div>
# <div class="search_title hidden_pc" id="search_block">Search<i aria-hidden="true" class="fa fa-chevron-down"></i></div>
# <div class="portfolio-experiment" id="search_content">
# <!-- part number search -->
# <a href="/en-global/Product_Search_Engine/index/" title="by Part Number">
# <div>
# <p>Part Number<i aria-hidden="true" class="fa fa-arrow-circle-right"></i></p>
# </div>
# <span class="line -right"></span>
# <span class="line -top"></span>
# <span class="line -left"></span>
# <span class="line -bottom"></span>
# </a>
# <!-- characteristics search -->
# <a href="/en-global/Product_Search_Engine/specSearch/" title="by Characteristics">
# <div>
# <p>Characteristics<i aria-hidden="true" class="fa fa-arrow-circle-right"></i></p>
# </div>
# <span class="line -right"></span>
# <span class="line -top"></span>
# <span class="line -left"></span>
# <span class="line -bottom"></span>
# </a>
# <!-- Cross reference -->
# <a href="/en-global/Product_Search_Engine/crossReference/" title="by Cross Reference">
# <div>
# <p>Cross reference<i aria-hidden="true" class="fa fa-arrow-circle-right"></i></p>
# </div>
# <span class="line -right"></span>
# <span class="line -top"></span>
# <span class="line -left"></span>
# <span class="line -bottom"></span>
# </a>
# </div>
# </div>
# <div class="pro_type_block">
# <a class="active" href="/en-global/Inductor/index/emi_common?pro_type=1" title="">
# <h4>General</h4></a>
# <a class="" href="/en-global/Inductor/index/emi_common?pro_type=2" title=""><h4>Automotive Grade</h4></a>
# </div>
# </div>
# <!-- note -->
# <p class="note" data-target="#note" data-toggle="modal">Note<i aria-hidden="true" class="fa fa-exclamation-circle"></i></p>
# <div class="lv1_block">
# <a id="BWCU"></a>
# <div class="lv1_item">
# <div class="series_block clearfix">
# <p class="series_title">BWCU</p>
# <a class="common_btn download_btn" href="/upload/media/product/emi_common/file/BWCU_Series.pdf" target="_blank" title="Series Pdf">
# <span>
# 					Series Pdf
# 					<!-- Series Pdf -->
# <i aria-hidden="true" class="fa fa-file"></i>
# </span>
# </a>
# </div>
# <div class="series_info_block">
# <div class="img">
# <img alt="" src="/upload/media/product/emi_common/img/BWCU.jpg" title=""/>
# </div>
# <div class="info">
# <p>02_For USB 2.0,IEEE1394,LVDS HDMI1.4 <br/> 03_For USB 3.1,HDMI 2.0, IEEE1394b,LVDS <br/></p>
# </div>
# </div>
# <div>
# <table class="des_table">
# <thead>
# <tr>
# <th>Series</th>
# <th>Size Code (JIS/EIA)</th>
# <th>Impedance(Ω)</th>
# <th>Inductance(uH)</th>
# <th>RDC(Ω)</th>
# <th>Rated Current(mA)</th>
# <th class="hidden_pc"></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td class="ti" data-title="Series">
# <div class="apen"></div>
# <span>
# <a class="" href="/en-global/Inductor/SubSeries/emi_common/BWCU/BWCU_121008_02">BWCU_121008-02</a>
# </span>
# </td>
# <td class="" data-title="Size Code (JIS/EIA)">
# <div class="apen"></div>
# <span>
#
# 								1210/0504																							</span>
# </td>
# <td class="" data-title="Impedance(Ω)">
# <div class="apen"></div>
# <span>
#
# 								25~330																							</span>
# </td>
# <td class="" data-title="Inductance(uH)">
# <div class="apen"></div>
# <span>
#
# 								-																							</span>
# </td>
# <td class="" data-title="RDC(Ω)">
# <div class="apen"></div>
# <span>
#
# 								0.25~1.3																							</span>
# </td>
# <td class="" data-title="Rated Current(mA)">
# <div class="apen"></div>
# <span>
#
# 								100~400																							</span>
# </td>
# <td class="hidden_pc" data-title="">
# <div class="apen"></div>
# <span>
# <a class="common_more" href="/en-global/Inductor/SubSeries/emi_common/BWCU/BWCU_121008_02">More<i aria-hidden="true" class="fa fa-arrow-circle-right"></i></a>
# </span>
# </td>
# </tr>
# <tr>
# <td class="ti" data-title="Series">
# <div class="apen"></div>
# <span>
# <a class="" href="/en-global/Inductor/SubSeries/emi_common/BWCU/BWCU_160811_02">BWCU_160811-02</a>
# </span>
# </td>
# <td class="" data-title="Size Code (JIS/EIA)">
# <div class="apen"></div>
# <span>
#
# 								1608/0603																							</span>
# </td>
# <td class="" data-title="Impedance(Ω)">
# <div class="apen"></div>
# <span>
#
# 								25~220																							</span>
# </td>
# <td class="" data-title="Inductance(uH)">
# <div class="apen"></div>
# <span>
#
# 								-																							</span>
# </td>
# <td class="" data-title="RDC(Ω)">
# <div class="apen"></div>
# <span>
#
# 								0.077~0.209																							</span>
# </td>
# <td class="" data-title="Rated Current(mA)">
# <div class="apen"></div>
# <span>
#
# 								500																							</span>
# </td>
# <td class="hidden_pc" data-title="">
# <div class="apen"></div>
# <span>
# <a class="common_more" href="/en-global/Inductor/SubSeries/emi_common/BWCU/BWCU_160811_02">More<i aria-hidden="true" class="fa fa-arrow-circle-right"></i></a>
# </span>
# </td>
# </tr>
# <tr>
# <td class="ti" data-title="Series">
# <div class="apen"></div>
# <span>
# <a class="" href="/en-global/Inductor/SubSeries/emi_common/BWCU/BWCU_201212_02">BWCU_201212-02</a>
# </span>
# </td>
# <td class="" data-title="Size Code (JIS/EIA)">
# <div class="apen"></div>
# <span>
#
# 								2012/0805																							</span>
# </td>
# <td class="" data-title="Impedance(Ω)">
# <div class="apen"></div>
# <span>
#
# 								30~900																							</span>
# </td>
# <td class="" data-title="Inductance(uH)">
# <div class="apen"></div>
# <span>
#
# 								-																							</span>
# </td>
# <td class="" data-title="RDC(Ω)">
# <div class="apen"></div>
# <span>
#
# 								0.2~0.88																							</span>
# </td>
# <td class="" data-title="Rated Current(mA)">
# <div class="apen"></div>
# <span>
#
# 								80~450																							</span>
# </td>
# <td class="hidden_pc" data-title="">
# <div class="apen"></div>
# <span>
# <a class="common_more" href="/en-global/Inductor/SubSeries/emi_common/BWCU/BWCU_201212_02">More<i aria-hidden="true" class="fa fa-arrow-circle-right"></i></a>
# </span>
# </td>
# </tr>
# <tr>
# <td class="ti" data-title="Series">
# <div class="apen"></div>
# <span>
# <a class="" href="/en-global/Inductor/SubSeries/emi_common/BWCU/BWCU_231512_02">BWCU_231512-02</a>
# </span>
# </td>
# <td class="" data-title="Size Code (JIS/EIA)">
# <div class="apen"></div>
# <span>
#
# 								2012/0805																							</span>
# </td>
# <td class="" data-title="Impedance(Ω)">
# <div class="apen"></div>
# <span>
#
# 								30~260																							</span>
# </td>
# <td class="" data-title="Inductance(uH)">
# <div class="apen"></div>
# <span>
#
# 								-																							</span>
# </td>
# <td class="" data-title="RDC(Ω)">
# <div class="apen"></div>
# <span>
#
# 								0.2~0.6																							</span>
# </td>
# <td class="" data-title="Rated Current(mA)">
# <div class="apen"></div>
# <span>
#
# 								700~1300																							</span>
# </td>
# <td class="hidden_pc" data-title="">
# <div class="apen"></div>
# <span>
# <a class="common_more" href="/en-global/Inductor/SubSeries/emi_common/BWCU/BWCU_231512_02">More<i aria-hidden="true" class="fa fa-arrow-circle-right"></i></a>
# </span>
# </td>
# </tr>
# <tr>
# <td class="ti" data-title="Series">
# <div class="apen"></div>
# <span>
# <a class="" href="/en-global/Inductor/SubSeries/emi_common/BWCU/BWCU_321619_02">BWCU_321619-02</a>
# </span>
# </td>
# <td class="" data-title="Size Code (JIS/EIA)">
# <div class="apen"></div>
# <span>
#
# 								3216/1206																							</span>
# </td>
# <td class="" data-title="Impedance(Ω)">
# <div class="apen"></div>
# <span>
#
# 								90~2200																							</span>
# </td>
# <td class="" data-title="Inductance(uH)">
# <div class="apen"></div>
# <span>
#
# 								-																							</span>
# </td>
# <td class="" data-title="RDC(Ω)">
# <div class="apen"></div>
# <span>
#
# 								0.3~1.2																							</span>
# </td>
# <td class="" data-title="Rated Current(mA)">
# <div class="apen"></div>
# <span>
#
# 								200~370																							</span>
# </td>
# <td class="hidden_pc" data-title="">
# <div class="apen"></div>
# <span>
# <a class="common_more" href="/en-global/Inductor/SubSeries/emi_common/BWCU/BWCU_321619_02">More<i aria-hidden="true" class="fa fa-arrow-circle-right"></i></a>
# </span>
# </td>
# </tr>
# <tr>
# <td class="ti" data-title="Series">
# <div class="apen"></div>
# <span>
# <a class="" href="/en-global/Inductor/SubSeries/emi_common/BWCU/BWCU_201212_03">BWCU_201212-03</a>
# </span>
# </td>
# <td class="" data-title="Size Code (JIS/EIA)">
# <div class="apen"></div>
# <span>
#
# 								2012/0805																							</span>
# </td>
# <td class="" data-title="Impedance(Ω)">
# <div class="apen"></div>
# <span>
#
# 								50~130																							</span>
# </td>
# <td class="" data-title="Inductance(uH)">
# <div class="apen"></div>
# <span>
#
# 								-																							</span>
# </td>
# <td class="" data-title="RDC(Ω)">
# <div class="apen"></div>
# <span>
#
# 								0.2~0.4																							</span>
# </td>
# <td class="" data-title="Rated Current(mA)">
# <div class="apen"></div>
# <span>
#
# 								300~500																							</span>
# </td>
# <td class="hidden_pc" data-title="">
# <div class="apen"></div>
# <span>
# <a class="common_more" href="/en-global/Inductor/SubSeries/emi_common/BWCU/BWCU_201212_03">More<i aria-hidden="true" class="fa fa-arrow-circle-right"></i></a>
# </span>
# </td>
# </tr>
# <tr>
# <td class="ti" data-title="Series">
# <div class="apen"></div>
# <span>
# <a class="" href="/en-global/Inductor/SubSeries/emi_common/BWCU/BWCU_121008_03">BWCU_121008-03</a>
# </span>
# </td>
# <td class="" data-title="Size Code (JIS/EIA)">
# <div class="apen"></div>
# <span>
#
# 								1210/0504																							</span>
# </td>
# <td class="" data-title="Impedance(Ω)">
# <div class="apen"></div>
# <span>
#
# 								22~90																							</span>
# </td>
# <td class="" data-title="Inductance(uH)">
# <div class="apen"></div>
# <span>
#
# 								-																							</span>
# </td>
# <td class="" data-title="RDC(Ω)">
# <div class="apen"></div>
# <span>
#
# 								0.2~0.4																							</span>
# </td>
# <td class="" data-title="Rated Current(mA)">
# <div class="apen"></div>
# <span>
#
# 								250~400																							</span>
# </td>
# <td class="hidden_pc" data-title="">
# <div class="apen"></div>
# <span>
# <a class="common_more" href="/en-global/Inductor/SubSeries/emi_common/BWCU/BWCU_121008_03">More<i aria-hidden="true" class="fa fa-arrow-circle-right"></i></a>
# </span>
# </td>
# </tr>
# <tr>
# <td class="ti" data-title="Series">
# <div class="apen"></div>
# <span>
# <a class="" href="/en-global/Inductor/SubSeries/emi_common/BWCU/BWCU_322518_00">BWCU_322518-00</a>
# <span class="new_cla">NEW</span>
# </span>
# </td>
# <td class="" data-title="Size Code (JIS/EIA)">
# <div class="apen"></div>
# <span>
#
# 								3225/1210																							</span>
# </td>
# <td class="" data-title="Impedance(Ω)">
# <div class="apen"></div>
# <span>
#
# 								90~1000																							</span>
# </td>
# <td class="" data-title="Inductance(uH)">
# <div class="apen"></div>
# <span>
#
# 								-																							</span>
# </td>
# <td class="" data-title="RDC(Ω)">
# <div class="apen"></div>
# <span>
#
# 								0.08~0.25																							</span>
# </td>
# <td class="" data-title="Rated Current(mA)">
# <div class="apen"></div>
# <span>
#
# 								480~1000																							</span>
# </td>
# <td class="hidden_pc" data-title="">
# <div class="apen"></div>
# <span>
# <a class="common_more" href="/en-global/Inductor/SubSeries/emi_common/BWCU/BWCU_322518_00">More<i aria-hidden="true" class="fa fa-arrow-circle-right"></i></a>
# </span>
# </td>
# </tr>
# <tr>
# <td class="ti" data-title="Series">
# <div class="apen"></div>
# <span>
# <a class="" href="/en-global/Inductor/SubSeries/emi_common/BWCU/BWCU_252012_3P">BWCU_252012-3P</a>
# <span class="new_cla">NEW</span>
# </span>
# </td>
# <td class="" data-title="Size Code (JIS/EIA)">
# <div class="apen"></div>
# <span>
#
# 								2520/1008																							</span>
# </td>
# <td class="" data-title="Impedance(Ω)">
# <div class="apen"></div>
# <span>
#
# 								67~800																							</span>
# </td>
# <td class="" data-title="Inductance(uH)">
# <div class="apen"></div>
# <span>
#
# 								-																							</span>
# </td>
# <td class="" data-title="RDC(Ω)">
# <div class="apen"></div>
# <span>
#
# 								0.16~1.6																							</span>
# </td>
# <td class="" data-title="Rated Current(mA)">
# <div class="apen"></div>
# <span>
#
# 								150~500																							</span>
# </td>
# <td class="hidden_pc" data-title="">
# <div class="apen"></div>
# <span>
# <a class="common_more" href="/en-global/Inductor/SubSeries/emi_common/BWCU/BWCU_252012_3P">More<i aria-hidden="true" class="fa fa-arrow-circle-right"></i></a>
# </span>
# </td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <a id="BWCU_Power_line"></a>
# <div class="lv1_item">
# <div class="series_block clearfix">
# <p class="series_title">BWCU_Power line</p>
# <a class="common_btn download_btn" href="/upload/media/product/emi_common/file/BWCU_Power_Series.pdf" target="_blank" title="Series Pdf">
# <span>
# 					Series Pdf
# 					<!-- Series Pdf -->
# <i aria-hidden="true" class="fa fa-file"></i>
# </span>
# </a>
# </div>
# <div class="series_info_block">
# <div class="img">
# <img alt="" src="/upload/media/product/emi_common/img/BWCU3.jpg" title=""/>
# </div>
# <div class="info">
# <p>For Power line noise countermeasure</p>
# </div>
# </div>
# <div>
# <table class="des_table">
# <thead>
# <tr>
# <th>Series</th>
# <th>Size Code (JIS/EIA)</th>
# <th>Impedance(Ω)</th>
# <th>Inductance(uH)</th>
# <th>RDC(Ω)</th>
# <th>Rated Current(mA)</th>
# <th class="hidden_pc"></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td class="ti" data-title="Series">
# <div class="apen"></div>
# <span>
# <a class="" href="/en-global/Inductor/SubSeries/emi_common/BWCU_Power_line/BWCU_322518_00">BWCU_322518-00</a>
# <span class="new_cla">NEW</span>
# </span>
# </td>
# <td class="" data-title="Size Code (JIS/EIA)">
# <div class="apen"></div>
# <span>
#
# 								3225/1210																							</span>
# </td>
# <td class="" data-title="Impedance(Ω)">
# <div class="apen"></div>
# <span>
#
# 								90~1000																							</span>
# </td>
# <td class="" data-title="Inductance(uH)">
# <div class="apen"></div>
# <span>
#
# 								-																							</span>
# </td>
# <td class="" data-title="RDC(Ω)">
# <div class="apen"></div>
# <span>
#
# 								0.08~0.25																							</span>
# </td>
# <td class="" data-title="Rated Current(mA)">
# <div class="apen"></div>
# <span>
#
# 								600~1000																							</span>
# </td>
# <td class="hidden_pc" data-title="">
# <div class="apen"></div>
# <span>
# <a class="common_more" href="/en-global/Inductor/SubSeries/emi_common/BWCU_Power_line/BWCU_322518_00">More<i aria-hidden="true" class="fa fa-arrow-circle-right"></i></a>
# </span>
# </td>
# </tr>
# <tr>
# <td class="ti" data-title="Series">
# <div class="apen"></div>
# <span>
# <a class="" href="/en-global/Inductor/SubSeries/emi_common/BWCU_Power_line/BWCU_252012_3P">BWCU_252012-3P</a>
# <span class="new_cla">NEW</span>
# </span>
# </td>
# <td class="" data-title="Size Code (JIS/EIA)">
# <div class="apen"></div>
# <span>
#
# 								2520/1008																							</span>
# </td>
# <td class="" data-title="Impedance(Ω)">
# <div class="apen"></div>
# <span>
#
# 								67~800																							</span>
# </td>
# <td class="" data-title="Inductance(uH)">
# <div class="apen"></div>
# <span>
#
# 								-																							</span>
# </td>
# <td class="" data-title="RDC(Ω)">
# <div class="apen"></div>
# <span>
#
# 								0.16~1.6																							</span>
# </td>
# <td class="" data-title="Rated Current(mA)">
# <div class="apen"></div>
# <span>
#
# 								150~500																							</span>
# </td>
# <td class="hidden_pc" data-title="">
# <div class="apen"></div>
# <span>
# <a class="common_more" href="/en-global/Inductor/SubSeries/emi_common/BWCU_Power_line/BWCU_252012_3P">More<i aria-hidden="true" class="fa fa-arrow-circle-right"></i></a>
# </span>
# </td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <a id="BWCC"></a>
# <div class="lv1_item">
# <div class="series_block clearfix">
# <p class="series_title">BWCC</p>
# <a class="common_btn download_btn" href="/upload/media/product/emi_common/file/BWCC_Series.pdf" target="_blank" title="Series Pdf">
# <span>
# 					Series Pdf
# 					<!-- Series Pdf -->
# <i aria-hidden="true" class="fa fa-file"></i>
# </span>
# </a>
# </div>
# <div class="series_info_block">
# <div class="img">
# <img alt="" src="/upload/media/product/emi_common/img/BWCC0805.jpg" title=""/>
# </div>
# <div class="info">
# <p>For USB 2.0,IEEE1394,LVDS HDMI1.4</p>
# </div>
# </div>
# <div>
# <table class="des_table">
# <thead>
# <tr>
# <th>Series</th>
# <th>Size Code (JIS/EIA)</th>
# <th>Impedance(Ω)</th>
# <th>Inductance(uH)</th>
# <th>RDC(Ω)</th>
# <th>Rated Current(mA)</th>
# <th class="hidden_pc"></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td class="ti" data-title="Series">
# <div class="apen"></div>
# <span>
# <a class="" href="/en-global/Inductor/SubSeries/emi_common/BWCC/BWCC_201208">BWCC_201208</a>
# </span>
# </td>
# <td class="" data-title="Size Code (JIS/EIA)">
# <div class="apen"></div>
# <span>
#
# 								2012/0805																							</span>
# </td>
# <td class="" data-title="Impedance(Ω)">
# <div class="apen"></div>
# <span>
#
# 								30~260																							</span>
# </td>
# <td class="" data-title="Inductance(uH)">
# <div class="apen"></div>
# <span>
#
# 								-																							</span>
# </td>
# <td class="" data-title="RDC(Ω)">
# <div class="apen"></div>
# <span>
#
# 								0.2~0.6																							</span>
# </td>
# <td class="" data-title="Rated Current(mA)">
# <div class="apen"></div>
# <span>
#
# 								700~1300																							</span>
# </td>
# <td class="hidden_pc" data-title="">
# <div class="apen"></div>
# <span>
# <a class="common_more" href="/en-global/Inductor/SubSeries/emi_common/BWCC/BWCC_201208">More<i aria-hidden="true" class="fa fa-arrow-circle-right"></i></a>
# </span>
# </td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <a id="BWDM"></a>
# <div class="lv1_item">
# <div class="series_block clearfix">
# <p class="series_title">BWDM</p>
# <a class="common_btn download_btn" href="/upload/media/product/emi_common/file/BWDM_Series.pdf" target="_blank" title="Series Pdf">
# <span>
# 					Series Pdf
# 					<!-- Series Pdf -->
# <i aria-hidden="true" class="fa fa-file"></i>
# </span>
# </a>
# </div>
# <div class="series_info_block">
# <div class="img">
# <img alt="" src="/upload/media/product/emi_common/img/BWDM.jpg" title=""/>
# </div>
# <div class="info">
# <p></p>
# </div>
# </div>
# <div>
# <table class="des_table">
# <thead>
# <tr>
# <th>Series</th>
# <th>Size Code (JIS/EIA)</th>
# <th>Impedance(Ω)</th>
# <th>Inductance(uH)</th>
# <th>RDC(Ω)</th>
# <th>Rated Current(mA)</th>
# <th class="hidden_pc"></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td class="ti" data-title="Series">
# <div class="apen"></div>
# <span>
# <a class="" href="/en-global/Inductor/SubSeries/emi_common/BWDM/BWDM_341620">BWDM_341620</a>
# <span class="new_cla">NEW</span>
# </span>
# </td>
# <td class="" data-title="Size Code (JIS/EIA)">
# <div class="apen"></div>
# <span>
#
# 								3416/1306																							</span>
# </td>
# <td class="" data-title="Impedance(Ω)">
# <div class="apen"></div>
# <span>
#
# 								-																							</span>
# </td>
# <td class="" data-title="Inductance(uH)">
# <div class="apen"></div>
# <span>
#
# 								40~105																							</span>
# </td>
# <td class="" data-title="RDC(Ω)">
# <div class="apen"></div>
# <span>
#
# 								1.5~3																							</span>
# </td>
# <td class="" data-title="Rated Current(mA)">
# <div class="apen"></div>
# <span>
#
# 								120~300																							</span>
# </td>
# <td class="hidden_pc" data-title="">
# <div class="apen"></div>
# <span>
# <a class="common_more" href="/en-global/Inductor/SubSeries/emi_common/BWDM/BWDM_341620">More<i aria-hidden="true" class="fa fa-arrow-circle-right"></i></a>
# </span>
# </td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <a id="BPPM"></a>
# <div class="lv1_item">
# <div class="series_block clearfix">
# <p class="series_title">BPPM</p>
# <a class="common_btn download_btn" href="/upload/media/product/emi_common/file/BPPM_Series.pdf" target="_blank" title="Series Pdf">
# <span>
# 					Series Pdf
# 					<!-- Series Pdf -->
# <i aria-hidden="true" class="fa fa-file"></i>
# </span>
# </a>
# </div>
# <div class="series_info_block">
# <div class="img">
# <img alt="" src="/upload/media/product/emi_common/img/BPPM.jpg" title=""/>
# </div>
# <div class="info">
# <p>For DC Power Line Common Mode Filter</p>
# </div>
# </div>
# <div>
# <table class="des_table">
# <thead>
# <tr>
# <th>Series</th>
# <th>Size Code (JIS/EIA)</th>
# <th>Impedance(Ω)</th>
# <th>Inductance(uH)</th>
# <th>RDC(Ω)</th>
# <th>Rated Current(mA)</th>
# <th class="hidden_pc"></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td class="ti" data-title="Series">
# <div class="apen"></div>
# <span>
# <a class="" href="/en-global/Inductor/SubSeries/emi_common/BPPM/BPPM_050520">BPPM_050520</a>
# </span>
# </td>
# <td class="" data-title="Size Code (JIS/EIA)">
# <div class="apen"></div>
# <span>
#
# 								5050/2020																							</span>
# </td>
# <td class="" data-title="Impedance(Ω)">
# <div class="apen"></div>
# <span>
#
# 								100~1200																							</span>
# </td>
# <td class="" data-title="Inductance(uH)">
# <div class="apen"></div>
# <span>
#
# 								-																							</span>
# </td>
# <td class="" data-title="RDC(Ω)">
# <div class="apen"></div>
# <span>
#
# 								0.045~0.081																							</span>
# </td>
# <td class="" data-title="Rated Current(mA)">
# <div class="apen"></div>
# <span>
#
# 								1900~3000																							</span>
# </td>
# <td class="hidden_pc" data-title="">
# <div class="apen"></div>
# <span>
# <a class="common_more" href="/en-global/Inductor/SubSeries/emi_common/BPPM/BPPM_050520">More<i aria-hidden="true" class="fa fa-arrow-circle-right"></i></a>
# </span>
# </td>
# </tr>
# <tr>
# <td class="ti" data-title="Series">
# <div class="apen"></div>
# <span>
# <a class="" href="/en-global/Inductor/SubSeries/emi_common/BPPM/BPPM_070638">BPPM_070638</a>
# </span>
# </td>
# <td class="" data-title="Size Code (JIS/EIA)">
# <div class="apen"></div>
# <span>
#
# 								7060/2824																							</span>
# </td>
# <td class="" data-title="Impedance(Ω)">
# <div class="apen"></div>
# <span>
#
# 								70~3000																							</span>
# </td>
# <td class="" data-title="Inductance(uH)">
# <div class="apen"></div>
# <span>
#
# 								-																							</span>
# </td>
# <td class="" data-title="RDC(Ω)">
# <div class="apen"></div>
# <span>
#
# 								0.005~0.075																							</span>
# </td>
# <td class="" data-title="Rated Current(mA)">
# <div class="apen"></div>
# <span>
#
# 								900~15000																							</span>
# </td>
# <td class="hidden_pc" data-title="">
# <div class="apen"></div>
# <span>
# <a class="common_more" href="/en-global/Inductor/SubSeries/emi_common/BPPM/BPPM_070638">More<i aria-hidden="true" class="fa fa-arrow-circle-right"></i></a>
# </span>
# </td>
# </tr>
# <tr>
# <td class="ti" data-title="Series">
# <div class="apen"></div>
# <span>
# <a class="" href="/en-global/Inductor/SubSeries/emi_common/BPPM/BPPM_090748">BPPM_090748</a>
# </span>
# </td>
# <td class="" data-title="Size Code (JIS/EIA)">
# <div class="apen"></div>
# <span>
#
# 								9070/3628																							</span>
# </td>
# <td class="" data-title="Impedance(Ω)">
# <div class="apen"></div>
# <span>
#
# 								300~2700																							</span>
# </td>
# <td class="" data-title="Inductance(uH)">
# <div class="apen"></div>
# <span>
#
# 								-																							</span>
# </td>
# <td class="" data-title="RDC(Ω)">
# <div class="apen"></div>
# <span>
#
# 								0.006~0.086																							</span>
# </td>
# <td class="" data-title="Rated Current(mA)">
# <div class="apen"></div>
# <span>
#
# 								2000~6000																							</span>
# </td>
# <td class="hidden_pc" data-title="">
# <div class="apen"></div>
# <span>
# <a class="common_more" href="/en-global/Inductor/SubSeries/emi_common/BPPM/BPPM_090748">More<i aria-hidden="true" class="fa fa-arrow-circle-right"></i></a>
# </span>
# </td>
# </tr>
# <tr>
# <td class="ti" data-title="Series">
# <div class="apen"></div>
# <span>
# <a class="" href="/en-global/Inductor/SubSeries/emi_common/BPPM/BPPM_121164">BPPM_121164</a>
# </span>
# </td>
# <td class="" data-title="Size Code (JIS/EIA)">
# <div class="apen"></div>
# <span>
#
# 								1211/4844																							</span>
# </td>
# <td class="" data-title="Impedance(Ω)">
# <div class="apen"></div>
# <span>
#
# 								230~2700																							</span>
# </td>
# <td class="" data-title="Inductance(uH)">
# <div class="apen"></div>
# <span>
#
# 								-																							</span>
# </td>
# <td class="" data-title="RDC(Ω)">
# <div class="apen"></div>
# <span>
#
# 								0.0022~0.05																							</span>
# </td>
# <td class="" data-title="Rated Current(mA)">
# <div class="apen"></div>
# <span>
#
# 								1500~10000																							</span>
# </td>
# <td class="hidden_pc" data-title="">
# <div class="apen"></div>
# <span>
# <a class="common_more" href="/en-global/Inductor/SubSeries/emi_common/BPPM/BPPM_121164">More<i aria-hidden="true" class="fa fa-arrow-circle-right"></i></a>
# </span>
# </td>
# </tr>
# <tr>
# <td class="ti" data-title="Series">
# <div class="apen"></div>
# <span>
# <a class="" href="/en-global/Inductor/SubSeries/emi_common/BPPM/BPPM_151360">BPPM_151360</a>
# </span>
# </td>
# <td class="" data-title="Size Code (JIS/EIA)">
# <div class="apen"></div>
# <span>
#
# 								1513/6052																							</span>
# </td>
# <td class="" data-title="Impedance(Ω)">
# <div class="apen"></div>
# <span>
#
# 								300~1500																							</span>
# </td>
# <td class="" data-title="Inductance(uH)">
# <div class="apen"></div>
# <span>
#
# 								-																							</span>
# </td>
# <td class="" data-title="RDC(Ω)">
# <div class="apen"></div>
# <span>
#
# 								0.0038~0.009																							</span>
# </td>
# <td class="" data-title="Rated Current(mA)">
# <div class="apen"></div>
# <span>
#
# 								8500~13000																							</span>
# </td>
# <td class="hidden_pc" data-title="">
# <div class="apen"></div>
# <span>
# <a class="common_more" href="/en-global/Inductor/SubSeries/emi_common/BPPM/BPPM_151360">More<i aria-hidden="true" class="fa fa-arrow-circle-right"></i></a>
# </span>
# </td>
# </tr>
# <tr>
# <td class="ti" data-title="Series">
# <div class="apen"></div>
# <span>
# <a class="" href="/en-global/Inductor/SubSeries/emi_common/BPPM/BPPM_485023">BPPM_485023</a>
# </span>
# </td>
# <td class="" data-title="Size Code (JIS/EIA)">
# <div class="apen"></div>
# <span>
#
# 								4850/1920																							</span>
# </td>
# <td class="" data-title="Impedance(Ω)">
# <div class="apen"></div>
# <span>
#
# 								100~1500																							</span>
# </td>
# <td class="" data-title="Inductance(uH)">
# <div class="apen"></div>
# <span>
#
# 								-																							</span>
# </td>
# <td class="" data-title="RDC(Ω)">
# <div class="apen"></div>
# <span>
#
# 								0.01~0.04																							</span>
# </td>
# <td class="" data-title="Rated Current(mA)">
# <div class="apen"></div>
# <span>
#
# 								2000~6000																							</span>
# </td>
# <td class="hidden_pc" data-title="">
# <div class="apen"></div>
# <span>
# <a class="common_more" href="/en-global/Inductor/SubSeries/emi_common/BPPM/BPPM_485023">More<i aria-hidden="true" class="fa fa-arrow-circle-right"></i></a>
# </span>
# </td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <a id="BPPI"></a>
# <div class="lv1_item">
# <div class="series_block clearfix">
# <p class="series_title">BPPI</p>
# <a class="common_btn download_btn" href="/upload/media/product/emi_common/file/BPPI_Series.pdf" target="_blank" title="Series Pdf">
# <span>
# 					Series Pdf
# 					<!-- Series Pdf -->
# <i aria-hidden="true" class="fa fa-file"></i>
# </span>
# </a>
# </div>
# <div class="series_info_block">
# <div class="img">
# <img alt="" src="/upload/media/product/emi_common/img/BPPI.jpg" title=""/>
# </div>
# <div class="info">
# <p>For Power line noise countermeasure</p>
# </div>
# </div>
# <div>
# <table class="des_table">
# <thead>
# <tr>
# <th>Series</th>
# <th>Size Code (JIS/EIA)</th>
# <th>Impedance(Ω)</th>
# <th>Inductance(uH)</th>
# <th>RDC(Ω)</th>
# <th>Rated Current(mA)</th>
# <th class="hidden_pc"></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td class="ti" data-title="Series">
# <div class="apen"></div>
# <span>
# <a class="" href="/en-global/Inductor/SubSeries/emi_common/BPPI/BPPI_050525">BPPI_050525</a>
# </span>
# </td>
# <td class="" data-title="Size Code (JIS/EIA)">
# <div class="apen"></div>
# <span>
#
# 								4850/1920																							</span>
# </td>
# <td class="" data-title="Impedance(Ω)">
# <div class="apen"></div>
# <span>
#
# 								100~1500																							</span>
# </td>
# <td class="" data-title="Inductance(uH)">
# <div class="apen"></div>
# <span>
#
# 								-																							</span>
# </td>
# <td class="" data-title="RDC(Ω)">
# <div class="apen"></div>
# <span>
#
# 								0.009~0.04																							</span>
# </td>
# <td class="" data-title="Rated Current(mA)">
# <div class="apen"></div>
# <span>
#
# 								1500~6000																							</span>
# </td>
# <td class="hidden_pc" data-title="">
# <div class="apen"></div>
# <span>
# <a class="common_more" href="/en-global/Inductor/SubSeries/emi_common/BPPI/BPPI_050525">More<i aria-hidden="true" class="fa fa-arrow-circle-right"></i></a>
# </span>
# </td>
# </tr>
# <tr>
# <td class="ti" data-title="Series">
# <div class="apen"></div>
# <span>
# <a class="" href="/en-global/Inductor/SubSeries/emi_common/BPPI/BPPI_050545">BPPI_050545</a>
# </span>
# </td>
# <td class="" data-title="Size Code (JIS/EIA)">
# <div class="apen"></div>
# <span>
#
# 								4850/1920																							</span>
# </td>
# <td class="" data-title="Impedance(Ω)">
# <div class="apen"></div>
# <span>
#
# 								190~3000																							</span>
# </td>
# <td class="" data-title="Inductance(uH)">
# <div class="apen"></div>
# <span>
#
# 								0.6~6																							</span>
# </td>
# <td class="" data-title="RDC(Ω)">
# <div class="apen"></div>
# <span>
#
# 								0.02~0.2																							</span>
# </td>
# <td class="" data-title="Rated Current(mA)">
# <div class="apen"></div>
# <span>
#
# 								500~5000																							</span>
# </td>
# <td class="hidden_pc" data-title="">
# <div class="apen"></div>
# <span>
# <a class="common_more" href="/en-global/Inductor/SubSeries/emi_common/BPPI/BPPI_050545">More<i aria-hidden="true" class="fa fa-arrow-circle-right"></i></a>
# </span>
# </td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# <!-- Modal -->
# <div aria-hidden="true" aria-labelledby="exampleModalLabel" class="modal fade" id="note" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <div class="modal-header">
# <button aria-label="Close" class="close" data-dismiss="modal" type="button">
# </button>
# </div>
# <div class="modal-body">
# <p class="modal-title">Note</p>
# 				Please be sure to request approval specifications that provide further details of the products. Kindly note that the content of these specifications are subject to change or may be discontinued without prior notice. This product may not be designed/used in medical or high risk applications without Chilisin approval. Please contact our sales department before ordering.			</div>
# <div class="modal-footer">
# </div>
# </div>
# </div>
# </div> </div>
# </div>

# %%
HTML(str(html_output[0]))
# Out:
# <div class="container">
# <div class="banner">
# <img src="/upload/website/banner/chilisin_product_banner_18062116137.jpg"/>
# </div>
# <div class="unit">
# <div class="crumbs_block clearfix">
# <ul class="crumbs no_ul clearfix">
# <li>
# <a href="/en-global/home/index">
# 					Home					</a>
# </li>
# <li><a href="/en-global/Inductor/index">Products</a></li>
# </ul>
# </div>
# </div>
# <div class="main_content">
# <h1 class="main_title">EMI-Common Mode Choke</h1>
# <script type="text/javascript">
#
# 	$(window).load(function()
# 	{
# 		var url = window.location.toString();
# 	    var id = url.split('#')[1];
# 	   	if(id)
# 	   	{
# 		    var t = $('#'+id).offset().top;
# 		   $('html,body').animate({scrollTop:(t)}, 1000);
# 		}
# 	});
# </script>
# <!-- Search -->
# <div class="top_search_block">
# <div class="search_sel_block lv1 clearfix">
# <div class="search_title hidden_m">Search by : </div>
# <div class="search_title hidden_pc" id="search_block">Search<i aria-hidden="true" class="fa fa-chevron-down"></i></div>
# <div class="portfolio-experiment" id="search_content">
# <!-- part number search -->
# <a href="/en-global/Product_Search_Engine/index/" title="by Part Number">
# <div>
# <p>Part Number<i aria-hidden="true" class="fa fa-arrow-circle-right"></i></p>
# </div>
# <span class="line -right"></span>
# <span class="line -top"></span>
# <span class="line -left"></span>
# <span class="line -bottom"></span>
# </a>
# <!-- characteristics search -->
# <a href="/en-global/Product_Search_Engine/specSearch/" title="by Characteristics">
# <div>
# <p>Characteristics<i aria-hidden="true" class="fa fa-arrow-circle-right"></i></p>
# </div>
# <span class="line -right"></span>
# <span class="line -top"></span>
# <span class="line -left"></span>
# <span class="line -bottom"></span>
# </a>
# <!-- Cross reference -->
# <a href="/en-global/Product_Search_Engine/crossReference/" title="by Cross Reference">
# <div>
# <p>Cross reference<i aria-hidden="true" class="fa fa-arrow-circle-right"></i></p>
# </div>
# <span class="line -right"></span>
# <span class="line -top"></span>
# <span class="line -left"></span>
# <span class="line -bottom"></span>
# </a>
# </div>
# </div>
# <div class="pro_type_block">
# <a class="active" href="/en-global/Inductor/index/emi_common?pro_type=1" title="">
# <h4>General</h4></a>
# <a class="" href="/en-global/Inductor/index/emi_common?pro_type=2" title=""><h4>Automotive Grade</h4></a>
# </div>
# </div>
# <!-- note -->
# <p class="note" data-target="#note" data-toggle="modal">Note<i aria-hidden="true" class="fa fa-exclamation-circle"></i></p>
# <div class="lv1_block">
# <a id="BWCU"></a>
# <div class="lv1_item">
# <div class="series_block clearfix">
# <p class="series_title">BWCU</p>
# <a class="common_btn download_btn" href="/upload/media/product/emi_common/file/BWCU_Series.pdf" target="_blank" title="Series Pdf">
# <span>
# 					Series Pdf
# 					<!-- Series Pdf -->
# <i aria-hidden="true" class="fa fa-file"></i>
# </span>
# </a>
# </div>
# <div class="series_info_block">
# <div class="img">
# <img alt="" src="/upload/media/product/emi_common/img/BWCU.jpg" title=""/>
# </div>
# <div class="info">
# <p>02_For USB 2.0,IEEE1394,LVDS HDMI1.4 <br/> 03_For USB 3.1,HDMI 2.0, IEEE1394b,LVDS <br/></p>
# </div>
# </div>
# <div>
# <table class="des_table">
# <thead>
# <tr>
# <th>Series</th>
# <th>Size Code (JIS/EIA)</th>
# <th>Impedance(Ω)</th>
# <th>Inductance(uH)</th>
# <th>RDC(Ω)</th>
# <th>Rated Current(mA)</th>
# <th class="hidden_pc"></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td class="ti" data-title="Series">
# <div class="apen"></div>
# <span>
# <a class="" href="/en-global/Inductor/SubSeries/emi_common/BWCU/BWCU_121008_02">BWCU_121008-02</a>
# </span>
# </td>
# <td class="" data-title="Size Code (JIS/EIA)">
# <div class="apen"></div>
# <span>
#
# 								1210/0504																							</span>
# </td>
# <td class="" data-title="Impedance(Ω)">
# <div class="apen"></div>
# <span>
#
# 								25~330																							</span>
# </td>
# <td class="" data-title="Inductance(uH)">
# <div class="apen"></div>
# <span>
#
# 								-																							</span>
# </td>
# <td class="" data-title="RDC(Ω)">
# <div class="apen"></div>
# <span>
#
# 								0.25~1.3																							</span>
# </td>
# <td class="" data-title="Rated Current(mA)">
# <div class="apen"></div>
# <span>
#
# 								100~400																							</span>
# </td>
# <td class="hidden_pc" data-title="">
# <div class="apen"></div>
# <span>
# <a class="common_more" href="/en-global/Inductor/SubSeries/emi_common/BWCU/BWCU_121008_02">More<i aria-hidden="true" class="fa fa-arrow-circle-right"></i></a>
# </span>
# </td>
# </tr>
# <tr>
# <td class="ti" data-title="Series">
# <div class="apen"></div>
# <span>
# <a class="" href="/en-global/Inductor/SubSeries/emi_common/BWCU/BWCU_160811_02">BWCU_160811-02</a>
# </span>
# </td>
# <td class="" data-title="Size Code (JIS/EIA)">
# <div class="apen"></div>
# <span>
#
# 								1608/0603																							</span>
# </td>
# <td class="" data-title="Impedance(Ω)">
# <div class="apen"></div>
# <span>
#
# 								25~220																							</span>
# </td>
# <td class="" data-title="Inductance(uH)">
# <div class="apen"></div>
# <span>
#
# 								-																							</span>
# </td>
# <td class="" data-title="RDC(Ω)">
# <div class="apen"></div>
# <span>
#
# 								0.077~0.209																							</span>
# </td>
# <td class="" data-title="Rated Current(mA)">
# <div class="apen"></div>
# <span>
#
# 								500																							</span>
# </td>
# <td class="hidden_pc" data-title="">
# <div class="apen"></div>
# <span>
# <a class="common_more" href="/en-global/Inductor/SubSeries/emi_common/BWCU/BWCU_160811_02">More<i aria-hidden="true" class="fa fa-arrow-circle-right"></i></a>
# </span>
# </td>
# </tr>
# <tr>
# <td class="ti" data-title="Series">
# <div class="apen"></div>
# <span>
# <a class="" href="/en-global/Inductor/SubSeries/emi_common/BWCU/BWCU_201212_02">BWCU_201212-02</a>
# </span>
# </td>
# <td class="" data-title="Size Code (JIS/EIA)">
# <div class="apen"></div>
# <span>
#
# 								2012/0805																							</span>
# </td>
# <td class="" data-title="Impedance(Ω)">
# <div class="apen"></div>
# <span>
#
# 								30~900																							</span>
# </td>
# <td class="" data-title="Inductance(uH)">
# <div class="apen"></div>
# <span>
#
# 								-																							</span>
# </td>
# <td class="" data-title="RDC(Ω)">
# <div class="apen"></div>
# <span>
#
# 								0.2~0.88																							</span>
# </td>
# <td class="" data-title="Rated Current(mA)">
# <div class="apen"></div>
# <span>
#
# 								80~450																							</span>
# </td>
# <td class="hidden_pc" data-title="">
# <div class="apen"></div>
# <span>
# <a class="common_more" href="/en-global/Inductor/SubSeries/emi_common/BWCU/BWCU_201212_02">More<i aria-hidden="true" class="fa fa-arrow-circle-right"></i></a>
# </span>
# </td>
# </tr>
# <tr>
# <td class="ti" data-title="Series">
# <div class="apen"></div>
# <span>
# <a class="" href="/en-global/Inductor/SubSeries/emi_common/BWCU/BWCU_231512_02">BWCU_231512-02</a>
# </span>
# </td>
# <td class="" data-title="Size Code (JIS/EIA)">
# <div class="apen"></div>
# <span>
#
# 								2012/0805																							</span>
# </td>
# <td class="" data-title="Impedance(Ω)">
# <div class="apen"></div>
# <span>
#
# 								30~260																							</span>
# </td>
# <td class="" data-title="Inductance(uH)">
# <div class="apen"></div>
# <span>
#
# 								-																							</span>
# </td>
# <td class="" data-title="RDC(Ω)">
# <div class="apen"></div>
# <span>
#
# 								0.2~0.6																							</span>
# </td>
# <td class="" data-title="Rated Current(mA)">
# <div class="apen"></div>
# <span>
#
# 								700~1300																							</span>
# </td>
# <td class="hidden_pc" data-title="">
# <div class="apen"></div>
# <span>
# <a class="common_more" href="/en-global/Inductor/SubSeries/emi_common/BWCU/BWCU_231512_02">More<i aria-hidden="true" class="fa fa-arrow-circle-right"></i></a>
# </span>
# </td>
# </tr>
# <tr>
# <td class="ti" data-title="Series">
# <div class="apen"></div>
# <span>
# <a class="" href="/en-global/Inductor/SubSeries/emi_common/BWCU/BWCU_321619_02">BWCU_321619-02</a>
# </span>
# </td>
# <td class="" data-title="Size Code (JIS/

# %% [markdown]
# Now we use the Unstructured library to partition the HTML into Elements.
#
# Reference:
#
# [partition_html](https://docs.unstructured.io/open-source/core-functionality/partitioning#partition-html)

# %%
elements = partition_html(text=str(html_output[0]))

# %% [markdown]
# Let's define a few helper functions for examing the Elements

# %%
def print_elements(els: list) -> None:
    '''Print type and text of each element'''
    for i, el in enumerate(els):
        print(i, ' ', el.to_dict()['type'].upper(), ': ', el.text)

# %%
def print_element_json(element):
    '''Print JSON representation of an individual element'''
    print(json.dumps(element.to_dict(), indent=2))

# %%
print_elements(elements)
# Out:
# 0   LISTITEM :  Home
# 1   LISTITEM :  Products
# 2   TITLE :  EMI-Common Mode Choke
# 3   TITLE :  Search by :
# 4   TITLE :  Search
# 5   TITLE :  Part Number
# 6   TITLE :  Characteristics
# 7   TITLE :  Cross reference
# 8   TITLE :  General
# 9   TITLE :  Automotive Grade
# 10   TITLE :  Note
# 11   TITLE :  BWCU
# 12   TITLE :  Series Pdf
# 13   TITLE :  02_For USB 2.0,IEEE1394,LVDS HDMI1.4
# 14   TITLE :  03_For USB 3.1,HDMI 2.0, IEEE1394b,LVDS
# 15   TABLE :  Series Size Code (JIS/EIA) Impedance(Ω) Inductance(uH) RDC(Ω) Rated Current(mA) BWCU_121008-02 1210/0504 25~330 - 0.25~1.3 100~400 More BWCU_160811-02 1608/0603 25~220 - 0.077~0.209 500 More BWCU_201212-02 2012/0805 30~900 - 0.2~0.88 80~450 More BWCU_231512-02 2012/0805 30~260 - 0.2~0.6 700~1300 More BWCU_321619-02 3216/1206 90~2200 - 0.3~1.2 200~370 More BWCU_201212-03 2012/0805 50~130 - 0.2~0.4 300~500 More BWCU_121008-03 1210/0504 22~90 - 0.2~0.4 250~400 More BWCU_322518-00 NEW 3225/1210 90~1000 - 0.08~0.25 480~1000 More BWCU_252012-3P NEW 2520/1008 67~800 - 0.16~1.6 150~500 More
# 16   TITLE :  BWCU_Power line
# 17   TITLE :  Series Pdf
# 18   TITLE :  For Power line noise countermeasure
# 19   TABLE :  Series Size Code (JIS/EIA) Impedance(Ω) Inductance(uH) RDC(Ω) Rated Current(mA) BWCU_322518-00 NEW 3225/1210 90~1000 - 0.08~0.25 600~1000 More BWCU_252012-3P NEW 2520/1008 67~800 - 0.16~1.6 150~500 More
# 20   TITLE :  BWCC
# 21   TITLE :  Series Pdf
# 22   TITLE :  For USB 2.0,IEEE1394,LVDS HDMI1.4
# 23   TABLE :  Series Size Code (JIS/EIA) Impedance(Ω) Inductance(uH) RDC(Ω) Rated Current(mA) BWCC_201208 2012/0805 30~260 - 0.2~0.6 700~1300 More
# 24   TITLE :  BWDM
# 25   TITLE :  Series Pdf
# 26   TABLE :  Series Size Code (JIS/EIA) Impedance(Ω) Inductance(uH) RDC(Ω) Rated Current(mA) BWDM_341620 NEW 3416/1306 - 40~105 1.5~3 120~300 More
# 27   TITLE :  BPPM
# 28   TITLE :  Series Pdf
# 29   TITLE :  For DC Power Line Common Mode Filter
# 30   TABLE :  Series Size Code (JIS/EIA) Impedance(Ω) Inductance(uH) RDC(Ω) Rated Current(mA) BPPM_050520 5050/2020 100~1200 - 0.045~0.081 1900~3000 More BPPM_070638 7060/2824 70~3000 - 0.005~0.075 900~15000 More BPPM_090748 9070/3628 300~2700 - 0.006~0.086 2000~6000 More BPPM_121164 1211/4844 230~2700 - 0.0022~0.05 1500~10000 More BPPM_151360 1513/6052 300~1500 - 0.0038~0.009 8500~13000 More BPPM_485023 4850/1920 100~1500 - 0.01~0.04 2000~6000 More
# 31   TITLE :  BPPI
# 32   TITLE :  Series Pdf
# 33   TITLE :  For Power line noise countermeasure
# 34   TABLE :  Series Size Code (JIS/EIA) Impedance(Ω) Inductance(uH) RDC(Ω) Rated Current(mA) BPPI_050525 4850/1920 100~1500 - 0.009~0.04 1500~6000 More BPPI_050545 4850/1920 190~3000 0.6~6 0.02~0.2 500~5000 More
# 35   NARRATIVETEXT :  Note
# 				Please be sure to request approval specifications that provide further details of the products. Kindly note that the content of these specifications are subject to change or may be discontinued without prior notice. This product may not be designed/used in medical or high risk applications without Chilisin approval. Please contact our sales department before ordering.

# %%
len(elements)
# Out:
# 36

# %%
for element in elements:
    print_element_json(element)
    print('\n')
# Out:
# {
#   "type": "ListItem",
#   "element_id": "a205dbbfd0ab1d9556653f03607bc637",
#   "text": "Home",
#   "metadata": {
#     "category_depth": 1,
#     "link_texts": [
#       "\r\n\t\t\t\t\tHome\t\t\t\t\t"
#     ],
#     "link_urls": [
#       "/en-global/home/index"
#     ],
#     "link_start_indexes": [
#       0
#     ],
#     "languages": [
#       "eng"
#     ],
#     "filetype": "text/html"
#   }
# }
#
#
# {
#   "type": "ListItem",
#   "element_id": "b6465dc3bb053dffaf4495cb47290ebd",
#   "text": "Products",
#   "metadata": {
#     "category_depth": 1,
#     "link_texts": [
#       "Products"
#     ],
#     "link_urls": [
#       "/en-global/Inductor/index"
#     ],
#     "link_start_indexes": [
#       0
#     ],
#     "languages": [
#       "eng"
#     ],
#     "filetype": "text/html"
#   }
# }
#
#
# {
#   "type": "Title",
#   "element_id": "f8b9c87f4aab79e28b1828bb8f7884bd",
#   "text": "EMI-Common Mode Choke",
#   "metadata": {
#     "category_depth": 0,
#     "languages": [
#       "eng"
#     ],
#     "filetype": "text/html"
#   }
# }
#
#
# {
#   "type": "Title",
#   "element_id": "cd0943f8a679d0d9e79b7eb9b01a1984",
#   "text": "Search by :",
#   "metadata": {
#     "category_depth": 0,
#     "languages": [
#       "eng"
#     ],
#     "filetype": "text/html"
#   }
# }
#
#
# {
#   "type": "Title",
#   "element_id": "314f939ccc59cae01c294024521921ad",
#   "text": "Search",
#   "metadata": {
#     "category_depth": 0,
#     "languages": [
#       "eng"
#     ],
#     "filetype": "text/html"
#   }
# }
#
#
# {
#   "type": "Title",
#   "element_id": "df8d7042f3bcef788f2a1fcec7d647ae",
#   "text": "Part Number",
#   "metadata": {
#     "category_depth": 0,
#     "link_texts": [
#       "Part Number"
#     ],
#     "link_urls": [
#       "/en-global/Product_Search_Engine/index/"
#     ],
#     "link_start_indexes": [
#       -1
#     ],
#     "languages": [
#       "eng"
#     ],
#     "filetype": "text/html"
#   }
# }
#
#
# {
#   "type": "Title",
#   "element_id": "ca5229b4a389821dc4207f343eed7f81",
#   "text": "Characteristics",
#   "metadata": {
#     "category_depth": 0,
#     "link_texts": [
#       "Characteristics"
#     ],
#     "link_urls": [
#       "/en-global/Product_Search_Engine/specSearch/"
#     ],
#     "link_start_indexes": [
#       -1
#     ],
#     "languages": [
#       "eng"
#     ],
#     "filetype": "text/html"
#   }
# }
#
#
# {
#   "type": "Title",
#   "element_id": "62640150fb5d783c8cc143a8a091c1ad",
#   "text": "Cross reference",
#   "metadata": {
#     "category_depth": 0,
#     "link_texts": [
#       "Cross reference"
#     ],
#     "link_urls": [
#       "/en-global/Product_Search_Engine/crossReference/"
#     ],
#     "link_start_indexes": [
#       -1
#     ],
#     "languages": [
#       "eng"
#     ],
#     "filetype": "text/html"
#   }
# }
#
#
# {
#   "type": "Title",
#   "element_id": "6e319364a8ccf6f9a5da543f53df4c00",
#   "text": "General",
#   "metadata": {
#     "category_depth": 0,
#     "link_texts": [
#       "General"
#     ],
#     "link_urls": [
#       "/en-global/Inductor/index/emi_common?pro_type=1"
#     ],
#     "link_start_indexes": [
#       -1
#     ],
#     "languages": [
#       "eng"
#     ],
#     "filetype": "text/html"
#   }
# }
#
#
# {
#   "type": "Title",
#   "element_id": "56a194dade372e2c333720d6f91b7382",
#   "text": "Automotive Grade",
#   "metadata": {
#     "category_depth": 0,
#     "link_texts": [
#       "Automotive Grade"
#     ],
#     "link_urls": [
#       "/en-global/Inductor/index/emi_common?pro_type=2"
#     ],
#     "link_start_indexes": [
#       -1
#     ],
#     "languages": [
#       "eng"
#     ],
#     "filetype": "text/html"
#   }
# }
#
#
# {
#   "type": "Title",
#   "element_id": "f7204f534b23a5db9df985717b6c7634",
#   "text": "Note",
#   "metadata": {
#     "category_depth": 0,
#     "languages": [
#       "eng"
#     ],
#     "filetype": "text/html"
#   }
# }
#
#
# {
#   "type": "Title",
#   "element_id": "e2346f100f0c07c1899d7dba7c24a9a3",
#   "text": "BWCU",
#   "metadata": {
#     "category_depth": 0,
#     "languages": [
#       "eng"
#     ],
#     "filetype": "text/html"
#   }
# }
#
#
# {
#   "type": "Title",
#   "element_id": "73d256e726a0a03c69ff09af49751576",
#   "text": "Series Pdf",
#   "metadata": {
#     "category_depth": 0,
#     "emphasized_text_contents": [
#       "Series Pdf"
#     ],
#     "emphasized_text_tags": [
#       "span"
#     ],
#     "link_texts": [
#       "Series Pdf"
#     ],
#     "link_urls": [
#       "/upload/media/product/emi_common/file/BWCU_Series.pdf"
#     ],
#     "link_start_indexes": [
#       -1
#     ],
#     "languages": [
#       "eng"
#     ],
#     "filetype": "text/html"
#   }
# }
#
#
# {
#   "type": "Title",
#   "element_id": "b1382b4daa85571acc198c885fbce943",
#   "text": "02_For USB 2.0,IEEE1394,LVDS HDMI1.4",
#   "metadata": {
#     "category_depth": 0,
#     "languages": [
#       "eng"
#     ],
#     "filetype": "text/html"
#   }
# }
#
#
# {
#   "type": "Title",
#   "element_id": "445eda581e33f12b45d8fd013b6c040f",
#   "text": "03_For USB 3.1,HDMI 2.0, IEEE1394b,LVDS",
#   "metadata": {
#     "category_depth": 0,
#     "languages": [
#       "eng"
#     ],
#     "filetype": "text/html"
#   }
# }
#
#
# {
#   "type": "Table",
#   "element_id": "6c57bbce4633f7954f3f198418de29f8",
#   "text": "Series Size Code (JIS/EIA) Impedance(\u03a9) Inductance(uH) RDC(\u03a9) Rated Current(mA) BWCU_121008-02 1210/0504 25~330 - 0.25~1.3 100~400 More BWCU_160811-02 1608/0603 25~220 - 0.077~0.209 500 More BWCU_201212-02 2012/0805 30~900 - 0.2~0.88 80~450 More BWCU_231512-02 2012/0805 30~260 - 0.2~0.6 700~1300 More BWCU_321619-02 3216/1206 90~2200 - 0.3~1.2 200~370 More BWCU_201212-03 2012/0805 50~130 - 0.2~0.4 300~500 More BWCU_121008-03 1210/0504 22~90 - 0.2~0.4 250~400 More BWCU_322518-00 NEW 3225/1210 90~1000 - 0.08~0.25 480~1000 More BWCU_252012-3P NEW 2520/1008 67~800 - 0.16~1.6 150~500 More",
#   "metadata": {
#     "text_as_html": "<table><tr><td>Series</td><td>Size Code (JIS/EIA)</td><td>Impedance(\u03a9)</td><td>Inductance(uH)</td><td>RDC(\u03a9)</td><td>Rated Current(mA)</td><td></td></tr><tr><td>BWCU_121008-02</td><td>1210/0504</td><td>25~330</td><td>-</td><td>0.25~1.3</td><td>100~400</td><td>More</td></tr><tr><td>BWCU_160811-02</td><td>1608/0603</td><td>25~220</td><td>-</td><td>0.077~0.209</td><td>500</td><td>More</td></tr><tr><td>BWCU_201212-02</td><td>2012/0805</td><td>30~900</td><td>-</td><td>0.2~0.88</td><td>80~450</td><td>More</td></tr><tr><td>BWCU_231512-02</td><td>2012/0805</td><td>30~260</td><td>-</td><td>0.2~0.6</td><td>700~1300</td><td>More</td></t
More",
#   "metadata": {
#     "text_as_html": "<table><tr><td>Series</td><td>Size Code (JIS/EIA)</td><td>Impedance(\u03a9)</td><td>Inductance(uH)</td><td>RDC(\u03a9)</td><td>Rated Current(mA)</td><td></td></tr><tr><td>BPPM_050520</td><td>5050/2020</td><td>100~1200</td><td>-</td><td>0.045~0.081</td><td>1900~3000</td><td>More</td></tr><tr><td>BPPM_070638</td><td>7060/2824</td><td>70~3000</td><td>-</td><td>0.005~0.075</td><td>900~15000</td><td>More</td></tr><tr><td>BPPM_090748</td><td>9070/3628</td><td>300~2700</td><td>-</td><td>0.006~0.086</td><td>2000~6000</td><td>More</td></tr><tr><td>BPPM_121164</td><td>1211/4844</td><td>230~2700</td><td>-</td><td>0.0022~0.05</td><td>1500~10000</td><td>More</td></tr><tr><td>BPPM_151360</td><td>1513/6052</td><td>300~1500</td><td>-</td><td>0.0038~0.009</td><td>8500~13000</td><td>More</td></tr><tr><td>BPPM_485023</td><td>4850/1920</td><td>100~1500</td><td>-</td><td>0.01~0.04</td><td>2000~6000</td><td>More</td></tr></table>",
#     "languages": [
#       "eng"
#     ],
#     "parent_id": "32e9c3b1e75fc0698c0490421c73abfb",
#     "filetype": "text/html"
#   }
# }
#
#
# {
#   "type": "Title",
#   "element_id": "21cbf08ab0134f3671c76873e181ff4c",
#   "text": "BPPI",
#   "metadata": {
#     "category_depth": 0,
#     "languages": [
#       "eng"
#     ],
#     "filetype": "text/html"
#   }
# }
#
#
# {
#   "type": "Title",
#   "element_id": "06efc9ee64d9f720cdc7bf8ffea6abc5",
#   "text": "Series Pdf",
#   "metadata": {
#     "category_depth": 0,
#     "emphasized_text_contents": [
#       "Series Pdf"
#     ],
#     "emphasized_text_tags": [
#       "span"
#     ],
#     "link_texts": [
#       "Series Pdf"
#     ],
#     "link_urls": [
#       "/upload/media/product/emi_common/file/BPPI_Series.pdf"
#     ],
#     "link_start_indexes": [
#       -1
#     ],
#     "languages": [
#       "eng"
#     ],
#     "filetype": "text/html"
#   }
# }
#
#
# {
#   "type": "Title",
#   "element_id": "416029e234ce4abc8a4613a13aa45cfa",
#   "text": "For Power line noise countermeasure",
#   "metadata": {
#     "category_depth": 0,
#     "languages": [
#       "eng"
#     ],
#     "filetype": "text/html"
#   }
# }
#
#
# {
#   "type": "Table",
#   "element_id": "f98dac0d5e1b16fff7572c8747bbbf40",
#   "text": "Series Size Code (JIS/EIA) Impedance(\u03a9) Inductance(uH) RDC(\u03a9) Rated Current(mA) BPPI_050525 4850/1920 100~1500 - 0.009~0.04 1500~6000 More BPPI_050545 4850/1920 190~3000 0.6~6 0.02~0.2 500~5000 More",
#   "metadata": {
#     "text_as_html": "<table><tr><td>Series</td><td>Size Code (JIS/EIA)</td><td>Impedance(\u03a9)</td><td>Inductance(uH)</td><td>RDC(\u03a9)</td><td>Rated Current(mA)</td><td></td></tr><tr><td>BPPI_050525</td><td>4850/1920</td><td>100~1500</td><td>-</td><td>0.009~0.04</td><td>1500~6000</td><td>More</td></tr><tr><td>BPPI_050545</td><td>4850/1920</td><td>190~3000</td><td>0.6~6</td><td>0.02~0.2</td><td>500~5000</td><td>More</td></tr></table>",
#     "languages": [
#       "eng"
#     ],
#     "parent_id": "416029e234ce4abc8a4613a13aa45cfa",
#     "filetype": "text/html"
#   }
# }
#
#
# {
#   "type": "NarrativeText",
#   "element_id": "b053026c9c522e3f9fb04be0d86b5ab8",
#   "text": "Note\r\n\t\t\t\tPlease be sure to request approval specifications that provide further details of the products. Kindly note that the content of these specifications are subject to change or may be discontinued without prior notice. This product may not be designed/used in medical or high risk applications without Chilisin approval. Please contact our sales department before ordering.",
#   "metadata": {
#     "languages": [
#       "eng"
#     ],
#     "parent_id": "416029e234ce4abc8a4613a13aa45cfa",
#     "filetype": "text/html"
#   }
# }

# %% [markdown]
# Now let's convert the elements into chunks that are suitable for embedding.
# We will use the Unstructured Library chunk_by_title function.
#
# Reference:
#
# [chunk_by_title](https://docs.unstructured.io/open-source/core-functionality/chunking)

# %%
def elements2chunks(elements):
    '''
    Convert elements to chunks of text
    '''
    chunks = chunk_by_title(elements, 
                            combine_text_under_n_chars=100, 
                            max_characters=3000)
    return chunks

# %%
chunks = elements2chunks(elements)

# %%
def print_chunks(chunks):
    for i, chunk in enumerate(chunks):
        print('Chunk Number: ', i, ' ***', chunk.category.upper(), '****')
        if (chunk.category == 'Table'):
            print(chunk.metadata.text_as_html)
        else:
            print(chunk.text)
        print("\n\n" + "-"*80)

# %%
print_chunks(chunks)
# Out:
# Chunk Number:  0  *** COMPOSITEELEMENT ****
# Home
#
# Products
#
# EMI-Common Mode Choke
#
# Search by :
#
# Search
#
# Part Number
#
# Characteristics
#
# Cross reference
#
#
# --------------------------------------------------------------------------------
# Chunk Number:
><tr><td>Series</td><td>Size Code (JIS/EIA)</td><td>Impedance(Ω)</td><td>Inductance(uH)</td><td>RDC(Ω)</td><td>Rated Current(mA)</td><td></td></tr><tr><td>BPPI_050525</td><td>4850/1920</td><td>100~1500</td><td>-</td><td>0.009~0.04</td><td>1500~6000</td><td>More</td></tr><tr><td>BPPI_050545</td><td>4850/1920</td><td>190~3000</td><td>0.6~6</td><td>0.02~0.2</td><td>500~5000</td><td>More</td></tr></table>
#
#
# --------------------------------------------------------------------------------
# Chunk Number:  13  *** COMPOSITEELEMENT ****
# Note
# 				Please be sure to request approval specifications that provide further details of the products. Kindly note that the content of these specifications are subject to change or may be discontinued without prior notice. This product may not be designed/used in medical or high risk applications without Chilisin approval. Please contact our sales department before ordering.
#
#
# --------------------------------------------------------------------------------

# %%
for chunk in chunks:
    print_element_json(chunk)
# Out:
# {
#   "type": "CompositeElement",
#   "element_id": "0cc42e01-686a-45c1-9c0e-097bd56b85a2",
#   "text": "Home\n\nProducts\n\nEMI-Common Mode Choke\n\nSearch by :\n\nSearch\n\nPart Number\n\nCharacteristics\n\nCross reference",
#   "metadata": {
#     "filetype": "text/html",
#     "languages": [
#       "eng"
#     ],
#     "link_texts": [
#       "\r\n\t\t\t\t\tHome\t\t\t\t\t",
#       "Products",
#       "Part Number",
#       "Characteristics",
#       "Cross reference"
#     ],
#     "link_urls": [
#       "/en-global/home/index",
#       "/en-global/Inductor/index",
#       "/en-global/Product_Search_Engine/index/",
#       "/en-global/Product_Search_Engine/specSearch/",
#       "/en-global/Product_Search_Engine/crossReference/"
#     ],
#     "orig_elements": "..."
#   }
# }
# {
#   "type": "CompositeElement",
#   "element_id": "cfb2b2fe-ba9d-4922-94f0-d55388b6e28c",
#   "text": "General\n\nAutomotive Grade\n\nNote\n\nBWCU\n\nSeries Pdf\n\n02_For USB 2.0,IEEE1394,LVDS HDMI1.4\n\n03_For USB 3.1,HDMI 2.0, IEEE1394b,LVDS",
#   "metadata": {
#     "emphasized_text_contents": [
#       "Series Pdf"
#     ],
#     "emphasized_text_tags": [
#       "span"
#     ],
#     "filetype": "text/html",
#     "languages": [
#       "eng"
#     ],
#     "link_texts": [
#       "General",
#       "Automotive Grade",
#       "Series Pdf"
#     ],
#     "link_urls": [
#       "/en-global/Inductor/index/emi_common?pro_type=1",
#       "/en-global/Inductor/index/emi_common?pro_type=2",
#       "/upload/media/product/emi_common/file/BWCU_Series.pdf"
#     ],
#     "orig_elements": "..."
#   }
# }
# {
#   "type": "Table",
#   "element_id": "6fd83e49-0d5e-426c-ad7a-34969244c980",
#   "text": "Series Size Code (JIS/EIA) Impedance(\u03a9) Inductance(uH) RDC(\u03a9) Rated Current(mA) BWCU_121008-02 1210/0504 25~330 - 0.25~1.3 100~400 More BWCU_160811-02 1608/0603 25~220 - 0.077~0.209 500 More BWCU_201212-02 2012/0805 30~900 - 0.2~0.88 80~450 More BWCU_231512-02 2012/0805 30~260 - 0.2~0.6 700~1300 More BWCU_321619-02 3216/1206 90~2200 - 0.3~1.2 200~370 More BWCU_201212-03 2012/0805 50~130 - 0.2~0.4 300~500 More BWCU_121008-03 1210/0504 22~90 - 0.2~0.4 250~400 More BWCU_322518-00 NEW 3225/1210 90~1000 - 0.08~0.25 480~1000 More BWCU_252012-3P NEW 2520/1008 67~800 - 0.16~1.6 150~500 More",
#   "metadata": {
#     "text_as_html": "<table><tr><td>Series</td><td>Size Code (JIS/EIA)</td><td>Impedance(\u03a9)</td><td>Inductance(uH)</td><td>RDC(\u03a9)</td><td>Rated Current(mA)</td><td></td></tr><tr><td>BWCU_121008-02</td><td>1210/0504</td><td>25~330</td><td>-</td><td>0.25~1.3</td><td>100~400</td><td>More</td></tr><tr><td>BWCU_160811-02</td><td>1608/0603</td><td>25~220</td><td>-</td><td>0.077~0.209</td><td>500</td><td>More</td></tr><tr><td>BWCU_201212-02</td><td>2012/0805</td><td>30~900</td><td>-</td><td>0.2~0.88</td><td>80~450</td><td>More</td></tr><tr><td>BWCU_231512-02</td><td>2012/0805</td><td>30~260</td><td>-</td><td>0.2~0.6</td><td>700~1300</td><td>More</td></t

#   "metadata": {
#     "emphasized_text_contents": [
#       "Series Pdf"
#     ],
#     "emphasized_text_tags": [
#       "span"
#     ],
#     "filetype": "text/html",
#     "languages": [
#       "eng"
#     ],
#     "link_texts": [
#       "Series Pdf"
#     ],
#     "link_urls": [
#       "/upload/media/product/emi_common/file/BPPI_Series.pdf"
#     ],
#     "orig_elements": "..."
#   }
# }
# {
#   "type": "Table",
#   "element_id": "292e63be-fe91-4ae2-b6a8-643139eb86a8",
#   "text": "Series Size Code (JIS/EIA) Impedance(\u03a9) Inductance(uH) RDC(\u03a9) Rated Current(mA) BPPI_050525 4850/1920 100~1500 - 0.009~0.04 1500~6000 More BPPI_050545 4850/1920 190~3000 0.6~6 0.02~0.2 500~5000 More",
#   "metadata": {
#     "text_as_html": "<table><tr><td>Series</td><td>Size Code (JIS/EIA)</td><td>Impedance(\u03a9)</td><td>Inductance(uH)</td><td>RDC(\u03a9)</td><td>Rated Current(mA)</td><td></td></tr><tr><td>BPPI_050525</td><td>4850/1920</td><td>100~1500</td><td>-</td><td>0.009~0.04</td><td>1500~6000</td><td>More</td></tr><tr><td>BPPI_050545</td><td>4850/1920</td><td>190~3000</td><td>0.6~6</td><td>0.02~0.2</td><td>500~5000</td><td>More</td></tr></table>",
#     "languages": [
#       "eng"
#     ],
#     "filetype": "text/html",
#     "orig_elements": "..."
#   }
# }
# {
#   "type": "CompositeElement",
#   "element_id": "f4c1dc1b-d579-4eff-84db-e9728bb106c4",
#   "text": "Note\r\n\t\t\t\tPlease be sure to request approval specifications that provide further details of the products. Kindly note that the content of these specifications are subject to change or may be discontinued without prior notice. This product may not be designed/used in medical or high risk applications without Chilisin approval. Please contact our sales department before ordering.",
#   "metadata": {
#     "filetype": "text/html",
#     "languages": [
#       "eng"
#     ],
#     "orig_elements": "..."
#   }
# }

# %% [markdown]
# Let's do some cleanup on the text in the chunks

# %%
def clean_chunks(chunks):
    # Clean up
    strings2replace = ["Series Pdf"]
    for ch in chunks:
        for string2replace in strings2replace:
            if (string2replace in ch.text):
                x = ch.text.replace(string2replace, "")
                ch.text = x
    return chunks

# %%
new_chunks = clean_chunks(chunks)

# %%
for ch in new_chunks:
    print_element_json(ch)
# Out:
# {
#   "type": "CompositeElement",
#   "element_id": "0cc42e01-686a-45c1-9c0e-097bd56b85a2",
#   "text": "Home\n\nProducts\n\nEMI-Common Mode Choke\n\nSearch by :\n\nSearch\n\nPart Number\n\nCharacteristics\n\nCross reference",
#   "metadata": {
#     "filetype": "text/html",
#     "languages": [
#       "eng"
#     ],
#     "link_texts": [
#       "\r\n\t\t\t\t\tHome\t\t\t\t\t",
#       "Products",
#       "Part Number",
#       "Characteristics",
#       "Cross reference"
#     ],
#     "link_urls": [
#       "/en-global/home/index",
#       "/en-global/Inductor/index",
#       "/en-global/Product_Search_Engine/index/",
#       "/en-global/Product_Search_Engine/specSearch/",
#       "/en-global/Product_Search_Engine/crossReference/"
#     ],
#     "orig_elements": "..."
#   }
# }
# {
#   "type": "CompositeElement",
#   "element_id": "cfb2b2fe-ba9d-4922-94f0-d55388b6e28c",
#   "text": "General\n\nAutomotive Grade\n\nNote\n\nBWCU\n\n\n\n02_For USB 2.0,IEEE1394,LVDS HDMI1.4\n\n03_For USB 3.1,HDMI 2.0, IEEE1394b,LVDS",
#   "metadata": {
#     "emphasized_text_contents": [
#       "Series Pdf"
#     ],
#     "emphasized_text_tags": [
#       "span"
#     ],
#     "filetype": "text/html",
#     "languages": [
#       "eng"
#     ],
#     "link_texts": [
#       "General",
#       "Automotive Grade",
#       "Series Pdf"
#     ],
#     "link_urls": [
#       "/en-global/Inductor/index/emi_common?pro_type=1",
#       "/en-global/Inductor/index/emi_common?pro_type=2",
#       "/upload/media/product/emi_common/file/BWCU_Series.pdf"
#     ],
#     "orig_elements": "..."
#   }
# }
# {
#   "type": "Table",
#   "element_id": "6fd83e49-0d5e-426c-ad7a-34969244c980",
#   "text": "Series Size Code (JIS/EIA) Impedance(\u03a9) Inductance(uH) RDC(\u03a9) Rated Current(mA) BWCU_121008-02 1210/0504 25~330 - 0.25~1.3 100~400 More BWCU_160811-02 1608/0603 25~220 - 0.077~0.209 500 More BWCU_201212-02 2012/0805 30~900 - 0.2~0.88 80~450 More BWCU_231512-02 2012/0805 30~260 - 0.2~0.6 700~1300 More BWCU_321619-02 3216/1206 90~2200 - 0.3~1.2 200~370 More BWCU_201212-03 2012/0805 50~130 - 0.2~0.4 300~500 More BWCU_121008-03 1210/0504 22~90 - 0.2~0.4 250~400 More BWCU_322518-00 NEW 3225/1210 90~1000 - 0.08~0.25 480~1000 More BWCU_252012-3P NEW 2520/1008 67~800 - 0.16~1.6 150~500 More",
#   "metadata": {
#     "text_as_html": "<table><tr><td>Series</td><td>Size Code (JIS/EIA)</td><td>Impedance(\u03a9)</td><td>Inductance(uH)</td><td>RDC(\u03a9)</td><td>Rated Current(mA)</td><td></td></tr><tr><td>BWCU
td><td>4850/1920</td><td>100~1500</td><td>-</td><td>0.01~0.04</td><td>2000~6000</td><td>More</td></tr></table>",
#     "languages": [
#       "eng"
#     ],
#     "filetype": "text/html",
#     "orig_elements": "..."
#   }
# }
# {
#   "type": "CompositeElement",
#   "element_id": "dedef7ee-952c-4d0e-81b8-941988c01b6b",
#   "text": "BPPI\n\n\n\nFor Power line noise countermeasure",
#   "metadata": {
#     "emphasized_text_contents": [
#       "Series Pdf"
#     ],
#     "emphasized_text_tags": [
#       "span"
#     ],
#     "filetype": "text/html",
#     "languages": [
#       "eng"
#     ],
#     "link_texts": [
#       "Series Pdf"
#     ],
#     "link_urls": [
#       "/upload/media/product/emi_common/file/BPPI_Series.pdf"
#     ],
#     "orig_elements": "..."
#   }
# }
# {
#   "type": "Table",
#   "element_id": "292e63be-fe91-4ae2-b6a8-643139eb86a8",
#   "text": "Series Size Code (JIS/EIA) Impedance(\u03a9) Inductance(uH) RDC(\u03a9) Rated Current(mA) BPPI_050525 4850/1920 100~1500 - 0.009~0.04 1500~6000 More BPPI_050545 4850/1920 190~3000 0.6~6 0.02~0.2 500~5000 More",
#   "metadata": {
#     "text_as_html": "<table><tr><td>Series</td><td>Size Code (JIS/EIA)</td><td>Impedance(\u03a9)</td><td>Inductance(uH)</td><td>RDC(\u03a9)</td><td>Rated Current(mA)</td><td></td></tr><tr><td>BPPI_050525</td><td>4850/1920</td><td>100~1500</td><td>-</td><td>0.009~0.04</td><td>1500~6000</td><td>More</td></tr><tr><td>BPPI_050545</td><td>4850/1920</td><td>190~3000</td><td>0.6~6</td><td>0.02~0.2</td><td>500~5000</td><td>More</td></tr></table>",
#     "languages": [
#       "eng"
#     ],
#     "filetype": "text/html",
#     "orig_elements": "..."
#   }
# }
# {
#   "type": "CompositeElement",
#   "element_id": "f4c1dc1b-d579-4eff-84db-e9728bb106c4",
#   "text": "Note\r\n\t\t\t\tPlease be sure to request approval specifications that provide further details of the products. Kindly note that the content of these specifications are subject to change or may be discontinued without prior notice. This product may not be designed/used in medical or high risk applications without Chilisin approval. Please contact our sales department before ordering.",
#   "metadata": {
#     "filetype": "text/html",
#     "languages": [
#       "eng"
#     ],
#     "orig_elements": "..."
#   }
# }

# %% [markdown]
# Further cleanup to combine a table with its title text.

# %%
def combine_chunks(chunks):
    '''Combining tables with their title
       Take advantage of that the chunk prior to a 
       table is its title.
       The text of the chunk becomes the title
       text_as_html in metadata will stay
    '''
    chunks2remove = []
    for i in range(len(chunks)):
        if(chunks[i].to_dict()['type'] == 'Table'):
            chunks[i].text = chunks[i-1].text
            chunks2remove.append(i-1)
    new_chunks = [chunk for i, chunk in enumerate(chunks) if i not in chunks2remove ]
    return new_chunks

# %%
new_new_chunks = combine_chunks(new_chunks)

# %%
for chunk in new_new_chunks:
    print_element_json(chunk)
# Out:
# {
#   "type": "CompositeElement",
#   "element_id": "0cc42e01-686a-45c1-9c0e-097bd56b85a2",
#   "text": "Home\n\nProducts\n\nEMI-Common Mode Choke\n\nSearch by :\n\nSearch\n\nPart Number\n\nCharacteristics\n\nCross reference",
#   "metadata": {
#     "filetype": "text/html",
#     "languages": [
#       "eng"
#     ],
#     "link_texts": [
#       "\r\n\t\t\t\t\tHome\t\t\t\t\t",
#       "Products",
#       "Part Number",
#       "Characteristics",
#       "Cross reference"
#     ],
#     "link_urls": [
#       "/en-global/home/index",
#       "/en-global/Inductor/index",
#       "/en-global/Product_Search_Engine/index/",
#       "/en-global/Product_Search_Engine/specSearch/",
#       "/en-global/Product_Search_Engine/crossReference/"
#     ],
#     "orig_elements": "..."
#   }
# }
# {
#   "type": "Table",
#   "element_id": "6fd83e49-0d5e-426c-ad7a-34969244c980",
#   "text": "General\n\nAutomotive Grade\n\nNote\n\nBWCU\n\n\n\n02_For USB 2.0,IEEE1394,LVDS HDMI1.4\n\n03_For USB 3.1,HDMI 2.0, IEEE1394b,LVDS",
#   "metadata": {
#     "text_as_html": "<table><tr><td>Series</td><td>Size Code (JIS/EIA)</td><td>Impedance(\u03a9)</td><td>Inductance(uH)</td><td>RDC(\u03a9)</td><td>Rated Current(mA)</td><td></td></tr><tr><td>BWCU
td><td>4850/1920</td><td>100~1500</td><td>-</td><td>0.009~0.04</td><td>1500~6000</td><td>More</td></tr><tr><td>BPPI_050545</td><td>4850/1920</td><td>190~3000</td><td>0.6~6</td><td>0.02~0.2</td><td>500~5000</td><td>More</td></tr></table>",
#     "languages": [
#       "eng"
#     ],
#     "filetype": "text/html",
#     "orig_elements": "..."
#   }
# }
# {
#   "type": "CompositeElement",
#   "element_id": "f4c1dc1b-d579-4eff-84db-e9728bb106c4",
#   "text": "Note\r\n\t\t\t\tPlease be sure to request approval specifications that provide further details of the products. Kindly note that the content of these specifications are subject to change or may be discontinued without prior notice. This product may not be designed/used in medical or high risk applications without Chilisin approval. Please contact our sales department before ordering.",
#   "metadata": {
#     "filetype": "text/html",
#     "languages": [
#       "eng"
#     ],
#     "orig_elements": "..."
#   }
# }

# %%
def chunks2docs(chunks):
    docs = []
    for chunk in chunks:
        if(chunk.to_dict()['type'] == 'Table'):
            table_metadata = {'source':html_source, 'text_as_html': chunk.to_dict()['metadata']['text_as_html']}
            docs.append(Document(page_content=chunk.text,
                                    metadata=table_metadata))
        else:
            metadata = {'source':html_source}
            docs.append(Document(page_content=chunk.text,
                                        metadata=metadata))
    return docs

# %%
docs = chunks2docs(new_new_chunks)

# %%
docs
# Out:
# [Document(page_content='Home\n\nProducts\n\nEMI-Common Mode Choke\n\nSearch by :\n\nSearch\n\nPart Number\n\nCharacteristics\n\nCross reference', metadata={'source': 'https://www.chilisin.com/en-global/Inductor/index/emi_common'}),
#  Document(page_content='General\n\nAutomotive Grade\n\nNote\n\nBWCU\n\n\n\n02_For USB 2.0,IEEE1394,LVDS HDMI1.4\n\n03_For USB 3.1,HDMI 2.0, IEEE1394b,LVDS', metadata={'source': 'https://www.chilisin.com/en-global/Inductor/index/emi_common', 'text_as_html': '<table><tr><td>Series</td><td>Size Code (JIS/EIA)</td><td>Impedance(Ω)</td><td>Inductance(uH)</td><td>RDC(Ω)</td><td>Rated Current(mA)</td><td></td></tr><tr><td>BWCU_121008-02</td><td>1210/0504</td><td>25~330</td><td>-</td><td>0.25~1.3</td><td>100~400</td><td>More</td></tr><tr><td>BWCU_160811-02</td><td>1608/0603</td><td>25~220</td><td>-</td><td>0.077~0.209</td><td>500</td><td>More</td></tr><tr><td>BWCU_201212-02</td><td>2012/0805</td><td>30~900</td><td>-</td><td>0.2~0.88</td><td>80~450</td><td>More</td></tr><tr><td>BWCU_231512-02</td><td>2012/0805</td><td>30~260</td><td>-</td><td>0.2~0.6</td><td>700~1300</td><td>More</td></tr><tr><td>BWCU_321619-02</td><td>3216/1206</td><td>90~2200</td><td>-</td><td>0.3~1.2</td><td>200~370</td><td>More</td></tr><tr><td>BWCU_201212-03</td><td>2012/0805</td><td>50~130</td><td>-</td><td>0.2~0.4</td><td>300~500</td><td>More</td></tr><tr><td>BWCU_121008-03</td><td>1210/0504</td><td>22~90</td><td>-</td><td>0.2~0.4</td><td>250~400</td><td>More</td></tr><tr><td>BWCU_322518-00 NEW</td><td>3225/1210</td><td>90~1000</td><td>-</td><td>0.08~0.25</td><td>480~1000</td><td>More</td></tr><tr><td>BWCU_252012-3P NEW</td><td>2520/1008</td><td>67~800</td><td>-</td><td>0.16~1.6</td><td>150~500</td><td>More</td></tr></table>'}),
#  Document(page_content='BWCU_Power line\n\n\n\nFor Power line noise countermeasure', metadata={'source': 'https://www.chilisin.com/en-global/Inductor/index/emi_common', 'text_as_html': '<table><tr><td>Series</td><td>Size Code (JIS/EIA)</td><td>Impedance(Ω)</td><td>Inductance(uH)</td><td>RDC(Ω)</td><td>Rated Current(mA)</td><td></td></tr><tr><td>BWCU_322518-00 NEW</td><td>3225/1210</td><td>90~1000</td><td>-</td><td>0.08~0.25</td><td>600~1000</td><td>More</td></tr><tr><td>BWCU_252012-3P NEW</td><td>2520/1008</td><td>67~800</td><td>-</td><td>0.16~1.6</td><td>150~500</td><td>More</td></tr></table>'}),
#  Document(page_content='BWCC\n\n\n\nFor USB 2.0,IEEE1394,LVDS HDMI1.4', metadata={'source': 'https://www.chilisin.com/en-global/Inductor/index/emi_common', 'text_as_html': '<table><tr><td>Series</td><td>Size Code (JIS/EIA)</td><td>Impedance(Ω)</td><td>Inductance(uH)</td><td>RDC(Ω)</td><td>Rated Current(mA)</td><td></td></tr><tr><td>BWCC_201208</td><td>2012/0805</td><td>30~260</td><td>-</td><td>0.2~0.6</td><td>700~1300</td><td>More</td></tr></table>'}),
#  Document(page_content='BWDM\n\n', metadata={'source': 'https://www.chilisin.com/en-global/Inductor/index/emi_common', 'text_as_html': '<table><tr><td>Series</td><td>Size Code (JIS/EIA)</td><td>Impedance(Ω)</td><td>Inductance(uH)</td><td>RDC(Ω)</td><td>Rated Current(mA)</td><td></td></tr><tr><td>BWDM_341620 NEW</td><td>3416/1306</td><td>-</td><td>40~105</td><td>1.5~3</td><td>120~300</td><td>More</td></tr></table>'}),
#  Document(page_content='BPPM\n\n\n\nFor DC Power Line Common Mode Filter', metadata={'source': 'https://www.chilisin.com/en-global/Inductor/index/emi_common', 'text_as_html': '<table><tr><td>Series</td><td>Size Code (JIS/EIA)</td><td>Impedance(Ω)</td><td>Inductance(uH)</td><td>RDC(Ω)</td><td>Rated Current(mA)</td><td></td></tr><tr><td>BPPM_050520</td><td>5050/2020</td><td>100~1200</td><td>-</td><td>0.045~0.081</td><td>1900~3000</td><td>More</td></tr><tr><td>BPPM_070638</td><td>7060/2824</td><td>70~3000</td><td>-</td><td>0.005~0.075</td><td>900~15000</td><td>More</td></tr><tr><td>BPPM_090748</td><td>9070/3628</td><td>300~2700</td><td>-</td><td>0.006~0.086</td><td>2000~6000</td><td>More</td></tr><tr><td>BPPM_121164</td><td>1211/4844</td><td>230~2700</td><td>-</td><td>0.0022~0.05</td><td>1500~10000</td><td>More</td></tr><tr><td>BPPM_151360</td><td>1513/6052</td><td>300~1500</td><td>-</td><td>0.0038~0.009</td><td>8500~13000</td><td>More</td></tr><tr><td>BPPM_485023</td><td>4850/1920</td><td>100~1500</td><td>-</td><td>0.01~0.04</td><td>2000~6000</td><td>More</td></tr></table>'}),
#  Document(page_content='BPPI\n\n\n\nFor Power line noise countermeasure', metadata={'source': 'https://www.chilisin.com/en-global/Inductor/index/emi_common', 'text_as_html': '<table><tr><td>Series</td><td>Size Code (JIS/EIA)</td><td>Impedance(Ω)</td><td>Inductance(uH)</td><td>RDC(Ω)</td><td>Rated Current(mA)</td><td></td></tr><tr><td>BPPI_050525</td><td>4850/1920</td><td>100~1500</td><td>-</td><td>0.009~0.04</td><td>1500~6000</td><td>More</td></tr><tr><td>BPPI_050545</td><td>4850/1920</td><td>190~3000</td><td>0.6~6</td><td>0.02~0.2</td><td>500~5000</td><td>More</td></tr></table>'}),
#  Document(page_content='Note\r\n\t\t\t\tPlease be sure to request approval specifications that provide further details of the products. Kindly note that the content of these specifications are subject to change or may be discontinued without prior notice. This product may not be designed/used in medical or high risk applications without Chilisin approval. Please contact our sales department before ordering.', metadata={'source': 'https://www.chilisin.com/en-global/Inductor/index/emi_common'})]

# %% [markdown]
# Now let's add the LangChain documents to the Chroma vector database.

# %%
def docs2db(docs, persist_directory:str):
    mydb = Chroma(embedding_function=OpenAIEmbeddings(),
                    persist_directory=persist_directory)
    ids = mydb.add_documents(docs)
    return ids

# %%
docs2db(docs, '../mydb')
# Out:
# ['b6df74cb-02c3-48a1-af90-d9888d7812c5',
#  '2a272af8-d134-436c-bcad-22ab4d5a7210',
#  'a46f1cae-d412-4dc5-8fd8-3c3017fdce81',
#  '7c80f1fc-4e5a-447f-9b29-5946950b42a6',
#  '8b1467dd-d483-4f0c-b60c-eb96ed40dcef',
#  '85d01aa9-4e83-45af-9698-9388db4ec382',
#  '5035b3ae-c15c-466e-a6d0-db887e74306c',
#  '7071d052-5301-4fae-ba97-b307123aa99b']
